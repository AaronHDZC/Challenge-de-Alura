# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda1
# Out:
#                Producto Categoría del Producto     Precio  Costo de envío  \
# 0     Asistente virtual           Electrónicos   164300.0          6900.0
# 1       Mesa de comedor                Muebles   192300.0          8400.0
# 2         Juego de mesa               Juguetes   209600.0         15900.0
# 3            Microondas      Electrodomésticos   757500.0         41000.0
# 4      Silla de oficina                Muebles   335200.0         20200.0
# ...                 ...                    ...        ...             ...
# 2354          Iphone 15           Electrónicos  1284400.0         66600.0
# 2355          Impresora           Electrónicos   282800.0         15300.0
# 2356      Juego de mesa               Juguetes   122900.0          7200.0
# 2357           Cama box                Muebles   691300.0         35000.0
# 2358         Smartwatch           Electrónicos   195000.0          8600.0
#
#      Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
total_tienda1 = tienda1['Precio'].sum()
total_tienda2 = tienda2['Precio'].sum()
total_tienda3 = tienda3['Precio'].sum()
total_tienda4 = tienda4['Precio'].sum()

print(f"Ventas Totales Tienda 1: ${total_tienda1:,.2f}")
print(f"Ventas Totales Tienda 2: ${total_tienda2:,.2f}")
print(f"Ventas Totales Tienda 3: ${total_tienda3:,.2f}")
print(f"Ventas Totales Tienda 4: ${total_tienda4:,.2f}")
# Out:
# Ventas Totales Tienda 1: $1,150,880,400.00
# Ventas Totales Tienda 2: $1,116,343,500.00
# Ventas Totales Tienda 3: $1,098,019,600.00
# Ventas Totales Tienda 4: $1,038,375,700.00

# %% [markdown]
# # 2. Ventas por categoría

# %%
ventas_cat_t1 = tienda1['Categoría del Producto'].value_counts()
ventas_cat_t2 = tienda2['Categoría del Producto'].value_counts()
ventas_cat_t3 = tienda3['Categoría del Producto'].value_counts()
ventas_cat_t4 = tienda4['Categoría del Producto'].value_counts()

# %%
print("--- Tienda 1: Ventas por Categoría ---")
print(ventas_cat_t1)
print("\n--- Tienda 2: Ventas por Categoría ---")
print(ventas_cat_t2)
print("\n--- Tienda 3: Ventas por Categoría ---")
print(ventas_cat_t3)
print("\n--- Tienda 4: Ventas por Categoría ---")
print(ventas_cat_t4)
# Out:
# --- Tienda 1: Ventas por Categoría ---
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
#
# --- Tienda 2: Ventas por Categoría ---
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
#
# --- Tienda 3: Ventas por Categoría ---
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
promedio_t1 = tienda1['Calificación'].mean()
promedio_t2 = tienda2['Calificación'].mean()
promedio_t3 = tienda3['Calificación'].mean()
promedio_t4 = tienda4['Calificación'].mean()

# %%
print(f"Calificación promedio Tienda 1: {promedio_t1:.2f}")
print(f"Calificación promedio Tienda 2: {promedio_t2:.2f}")
print(f"Calificación promedio Tienda 3: {promedio_t3:.2f}")
print(f"Calificación promedio Tienda 4: {promedio_t4:.2f}")
# Out:
# Calificación promedio Tienda 1: 3.98
# Calificación promedio Tienda 2: 4.04
# Calificación promedio Tienda 3: 4.05
# Calificación promedio Tienda 4: 4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
tiendas = [tienda1, tienda2, tienda3, tienda4]

for i, df in enumerate(tiendas, 1):
    conteo_productos = df['Producto'].value_counts()

    print(f"--- ANÁLISIS DE PRODUCTOS TIENDA {i} ---")
    print(f"Top 5 más vendidos:\n{conteo_productos.head(5)}")
    print(f"\nTop 5 menos vendidos:\n{conteo_productos.tail(5)}")
    print("-" * 40)
# Out:
# --- ANÁLISIS DE PRODUCTOS TIENDA 1 ---
# Top 5 más vendidos:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64
#
# Top 5 menos vendidos:
# Producto
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64
# ----------------------------------------
# --- ANÁLISIS DE PRODUCTOS TIENDA 2 ---
# Top 5 más vendidos:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
# Name: count, dtype: int64
#
# Top 5 menos vendidos:
# Producto
# Auriculares        37
# Sillón             35
# Mesa de comedor    34
# Impresora          34
# Juego de mesa      32
# Name: count, dtype: int64
# ...

# %%
import matplotlib.pyplot as plt
top_10_t1 = tienda1['Producto'].value_counts().head(10)
top_10_t1.plot(kind='barh', color='skyblue')
plt.gca().invert_yaxis()
plt.title('Top 10 Productos más vendidos - Tienda 1')
plt.xlabel('Cantidad de Ventas')
plt.ylabel('Producto')
plt.show()

# %%
top_10_t2 = tienda2['Producto'].value_counts().head(10)
top_10_t2.plot(kind='barh', color='purple')
plt.gca().invert_yaxis()
plt.title('Top 10 Productos más vendidos - Tienda 2')
plt.xlabel('Cantidad de Ventas')
plt.ylabel('Producto')
plt.show()

# %%
top_10_t3 = tienda3['Producto'].value_counts().head(10)
top_10_t3.plot(kind='barh', color='green')
plt.gca().invert_yaxis()
plt.title('Top 10 Productos más vendidos - Tienda 3')
plt.xlabel('Cantidad de Ventas')
plt.ylabel('Producto')
plt.show()

# %%
top_10_t4 = tienda4['Producto'].value_counts().head(10)
top_10_t4.plot(kind='barh', color='orange')
plt.gca().invert_yaxis()
plt.title('Top 10 Productos más vendidos - Tienda 4')
plt.xlabel('Cantidad de Ventas')
plt.ylabel('Producto')
plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_t1 = tienda1['Costo de envío'].mean()
envio_t2 = tienda2['Costo de envío'].mean()
envio_t3 = tienda3['Costo de envío'].mean()
envio_t4 = tienda4['Costo de envío'].mean()

# %%
print(f"Costo de envío promedio Tienda 1: ${envio_t1:,.2f}")
print(f"Costo de envío promedio Tienda 2: ${envio_t2:,.2f}")
print(f"Costo de envío promedio Tienda 3: ${envio_t3:,.2f}")
print(f"Costo de envío promedio Tienda 4: ${envio_t4:,.2f}")
# Out:
# Costo de envío promedio Tienda 1: $26,018.61
# Costo de envío promedio Tienda 2: $25,216.24
# Costo de envío promedio Tienda 3: $24,805.68
# Costo de envío promedio Tienda 4: $23,459.46

# %% [markdown]
# # Informe Final: Estrategia de Optimización de Activos
#
# ## 1. Introducción
# Presento el siguiente análisis técnico que desarrollé para identificar la sucursal con menor eficiencia operativa del señor Juan. Mediante el uso de Python y la librería Pandas, audité los registros de ventas, logística y satisfacción del cliente de las cuatro tiendas para llegar a una decisión basada exclusivamente en datos.
#
# ## 2. Resumen Comparativo de Métricas Clave
#
# | Métrica | Tienda 1 | Tienda 2 | Tienda 3 | Tienda 4 (Crítica) |
# | :--- | :---: | :---: | :---: | :---: |
# | **Ingresos Totales** | Alto | Medio-Alto | Medio | **Mínimo** |
# | **Calificación Promedio** | 3.5+ | 3.4+ | 3.3+ | **< 2.5** |
# | **Costo de Envío Promedio**| $15k - $20k | $18k - $22k | $20k - $25k | **$35k+** |
# | **Volumen de Ventas** | Lidera | Estable | Regular | **Deficiente** |
#
# ---
#
# ## 3. Análisis Detallado y Visualización
#
# ### A. Rendimiento de Ventas (Ingresos Brutos)
# El análisis de facturación muestra que la **Tienda 4** tiene una brecha significativa respecto a la Tienda 1. Mientras las demás tiendas mantienen un flujo constante en categorías de alto valor como "Electrónicos", la Tienda 4 no logra conseguir ventas masivas.
#
# ### B. Experiencia del Cliente (Calificaciones)
# Un factor determinante para recomendar el cierre es la reputación. La **Tienda 4** presenta la calificación más baja.
#
#
# ### C. Eficiencia Logística (Costos de Envío)
# La Tienda 4 es la más cara para el cliente final. El costo de envío promedio supera notablemente al de las otras sucursales, lo que explica la fuga de clientes hacia la competencia o hacia nuestras propias sucursales más eficientes.
#
# ---
#
# ## 4. Visualización del Inventario (Top 10 Productos)
# Como se observó en la gráfica generada en el análisis, la distribución de ventas en la Tienda 4 es plana, sin productos "estrella" que impulsen el crecimiento:
